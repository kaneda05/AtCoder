# %% [markdown]
# # A

# %%
A,B = map(int,input().split())
if A%B == 0:
    print(A//B)
else:
    print(A//B+1)
# Out:
# 3

# %% [markdown]
# # B

# %%
 H,W = map(int,input().split())
 S = [input() for _ in range(H)]

# %% [markdown]
# # C

# %%
N, M = map(int,input().split())
S = [input() for _ in range(H)]

for i in range(N):
    cnt = 0
    for j in range(M):
            if S[i][j]==S[i+1][j]:
                cnt += 1
    if cnt<M-1:
        print("No")
        exit()

print("Yes")
